# %% [markdown]
# # Scrape and Summarize Wep Page Content using LLM

# %%
# get working dirctory
import os, sys
sys.path.append(os.path.abspath('..'))

# load modules
from app.scraper import Website
from app.summarizer import Summarize

# %% [markdown]
# ## Display Scraped wep page

# %%
# load web page content
# lets load classic short stories of Beyond the wall
url = "https://www.classicshorts.com/stories/btw.html"
website = Website(url)

# display web page
website.display_webpage()
# Out:
# Beyond the Wall--Ambrose Bierce (1842-1914)
# ...
# Beyond the Wall
# 🎥
# by
# Ambrose Bierce (1842-1914)
# Approximate Word Count: 3448
# M
# any years ago, on my way from
# Hongkong
# to New York, I passed a week in San Francisco.  A long time had gone by since I had been in that city, during which my ventures in the
# Orient
# had prospered beyond my hope; I was rich and could afford to revisit my own country to renew my friendship with such of the companions of my youth as still lived and remembered me with the old affection.  Chief of these, I hoped, was Mohun Dampier, an old schoolmate with whom I had held a
# desultory
# correspondence which had long ceased, as is the way of correspondence between men.  You may have observed that the
# indisposition
# to write a merely social letter is in the ratio of the square of the distance between you and your correspondent.  It is a law.
# I remembered Dampier as a handsome, strong young fellow of scholarly tastes, with an
# aversion
# ...

# %% [markdown]
# ## Summarize Wep page

# %%
# Let's just make sure the model is loaded
# !ollama pull llama3.2
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕████████████████▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕████████████████▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕████████████████▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕████████████████▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕████████████████▏   96 B
# pulling 34bb5ab01051... 100% ▕████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
# Summarize the loaded wep page
summary = Summarize(website)

# display the summary of the wep page
summary.summarize_using_ollama()
# Out:
# What a wonderful piece of Gothic horror! The story is a masterclass in atmospheric tension and psychological complexity, woven together by the narrator's dark emotions and philosophical musings.
#
# The tale begins with a narrator who becomes infatuated with a young woman living next door to him. He spends his entire existence trying to meet her and make her acquaintance, but she perpetually ignores him or remains invisible to him. The narrator's obsession grows until it becomes an all-consuming force in his life, driving him into despair and shame.
#
# The story takes a profound turn when the young woman dies, not from any direct connection between them, but rather as a result of a mysterious and symbolic act by her own hand. Her final request, to move her bed to the opposite side of the room, is interpreted by her family and attendants as a "vagary" of delirium, but in reality, it was a desperate attempt to reconnect with the narrator.
#
# ...
